# %%
import pandas as pd # data processing, CSV file I/O

# %% [markdown]
# ### Aufgabe 1: Erstellen und Drucken eines DataFrame
# Legen Sie ein DataFrame an, das Informationen zu 6 Personen enthält (Spalten: "Name", "Alter", "Stadt", "Einkommen"). Gehen Sie dabei von zwei oder drei Städten aus.

# %%
# Beispiel-Daten erzeugen
data = {
    "Name": 
    "Alter": 
    "Stadt": 
    "Einkommen": 
}

df = pd.DataFrame(data)

# %% [markdown]
# ### Aufgabe 2: Filtern von Daten
# Filtern Sie die Personen heraus, die älter als 30 Jahre sind und deren Einkommen über 50.000 liegt. Zeigen Sie diese Zeilen an.

# %%
# Neues Dataframe mit gefilterten Daten anlegen
filtered_df = 


# Drucken des gefilterten DataFrame
print("Gefilterte Personen:")
print(filtered_df)

# %% [markdown]
# ### Aufgabe 3: Hinzufügen einer neuen Spalte
# Erweitern Sie das folgende DataFrame um eine neue Spalte "EinkommenEuro", indem davon ausgegangen wird, dass das in der Spalte "Einkommen" gespeicherte Einkommen in US-Dollar vorliegt. Nutzen Sie dafür einen festen Wechselkurs (z. B. 1 USD = 0,92 Euro).

# %%
# Wechselkurs definieren


# Hinzufügen der neuen Spalte


# DataFrame anzeigen
print(df)

# %% [markdown]
# ### Aufgabe 4: Gruppieren und Aggregieren
# Gruppieren Sie die Daten nach Stadt, und berechneen Sie das durchschnittliche Gehalt pro Gruppe.

# %%
# Tipp: df.groupby



# Drucken des gruppierten DataFrame
print(grouped_df)

# %% [markdown]
# ### Aufgabe 5: Sortieren von Daten
# Sortieren Sie den DataFrame nach der Spalte "Alter" in aufsteigender Reihenfolge.

# %%
# Tipp: df.sort_values


# Drucken des sortierten DataFrame
print(sorted_df)

# %% [markdown]
# ### Aufgabe 6: Datensatz erweitern
# Fügen Sie zum gegeben DataFrame eine neue Zeile (neuen Datenpunkt) dazu. Lassen Sie dabei den Feld Alter leer.

# %%
# Neue Zeile definieren
neue_zeile = 

# Neue Zeile in einen DataFrame umwandeln
df_neue_zeile = 

# DataFrames zusammenführen
# Tipp: pd.concat
df_erweitert = 

# DataFrame anzeigen
print(df_erweitert)

# %% [markdown]
# ### Aufgabe 7: Fehlende Werte behandeln
# Ersetzen Sie im erweitertem Dataframe den fehlenden Wert in der Spalte "Alter" durch den Durchschnittswert der Spalte.

# %%
import numpy as np

# Ersetzen der fehlenden Werte


# Drucken des DataFrame
print(df)

# %% [markdown]
# ### Aufgabe 8: CSV-Dateien nutzen
# Laden Sie eigene CSV-Datei hoch und visualisieren Sie es.
